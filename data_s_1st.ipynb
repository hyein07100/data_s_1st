# %% [markdown]
# # ssl.py에 3가지 기능 추가하기

# %%
print('%80s'%'스페인어통번역학과 202001815 손혜인')
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


# LinkedList 클래스 정의
class LinkedList:

# 초기화 메소드
    def __init__(self):
        dummy = Node("dummy")
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

# delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
    # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    # size 메소드
    def size(self):
        return self.num_of_data 
    # traverse_all 메소드
    def traverse_all(self):
        curr_node = self.head
        while curr_node != None:
            print("({}) -> ".format(curr_node.data), end="")
            curr_node = curr_node.next
        print("null")
# LinkedList 객체 생성
my_list = LinkedList()
# 노드 추가
my_list.append(100)
my_list.append(72)
my_list.append(325)
# 리스트 출력
my_list.traverse_all()
# Out:
#                                                          스페인어통번역학과 202001815 손혜인
# (dummy) -> (100) -> (72) -> (325) -> null

# %% [markdown]
# -my_list.append()에 소수인 3.2 넣어봄 -> 정상 동작 // my_list.append(3.2)
#
# -my_list.append()에 음의 정수 -1 넣어봄 -> 정상 동작
#
# -my_list.append()에 가 넣어봄 -> 문자열이기 때문에 typeerror 발생

# %%
print('%80s'%'스페인어통번역학과 202001815 손혜인')
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


# LinkedList 클래스 정의
class LinkedList:

# 초기화 메소드
    def __init__(self):
        dummy = Node("dummy")
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

# delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
    # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    # size 메소드
    def size(self):
        return self.num_of_data 
    # traverse_all 메소드
    def traverse_all(self):
        curr_node = self.head.next
        print("head ->",end='')
        while curr_node != None:
            print("({}) -> ".format(curr_node.data), end="")
            curr_node = curr_node.next
        print("null")
# LinkedList 객체 생성
my_list = LinkedList()
# 노드 추가
my_list.append(100)
my_list.append(72)
my_list.append(325)
# 리스트 출력
my_list.traverse_all()
# Out:
#                                                          스페인어통번역학과 202001815 손혜인
# head ->(100) -> (72) -> (325) -> null

# %% [markdown]
# (dummy) -> (100) -> (72) -> (325) -> null 대신
#
# head ->(100) -> (72) -> (325) -> null로 코드 수정

# %%
print('%80s'%'스페인어통번역학과 202001815 손혜인')
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# LinkedList 클래스 정의
class LinkedList:

    # 초기화 메소드
    def __init__(self):
        dummy = Node("dummy")
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

    # delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
        # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    # size 메소드
    def size(self):
        return self.num_of_data 

    # traverse_all 메소드
    def traverse_all(self):
        curr_node = self.head.next
        print("head ->",end='')
        while curr_node != None:
            print("({}) -> ".format(curr_node.data), end="")
            curr_node = curr_node.next
        print("null")
    #insert_at 메소드
    def insert_at(position, new_data):
        if position <= 0:
            print("ERROR")
            return

        new_node = Node(new_data)

        if position == 1:
            new_node.next = self.head.next
            self.head.next = new_node
        else:
            self.current = self.head.next
            for i in range(1, position):
                self.before = self.current
                self.current = self.current.next

            new_node.next = self.current
            self.before.next = new_node

        self.num_of_data += 1
# LinkedList 객체 생성
my_list = LinkedList()

my_list.append(100)
my_list.append(72)
my_list.append(325)
my_list.insert_at(3,10000)
my_list.traverse_all()
# Out:
#                                                          스페인어통번역학과 202001815 손혜인
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 105
#     103 my_list.append(72)
#     104 my_list.append(325)
# --> 105 my_list.insert_at(3,10000)
#     106 my_list.traverse_all()
#
# TypeError: LinkedList.insert_at() takes 2 positional arguments but 3 were given

# %%
print('%80s'%'스페인어통번역학과 202001815 손혜인')
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# LinkedList 클래스 정의
class LinkedList:

    # 초기화 메소드
    def __init__(self):
        dummy = Node("dummy")
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

    # delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
        # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    # size 메소드
    def size(self):
        return self.num_of_data 

    # traverse_all 메소드
    def traverse_all(self):
        curr_node = self.head.next
        print("head ->",end='')
        while curr_node != None:
            print("({}) -> ".format(curr_node.data), end="")
            curr_node = curr_node.next
        print("null")
    #insert_at 메소드
    def insert_at(self,position, new_data):
        if position <= 0:
            print("ERROR")
            return

        new_node = Node(new_data)

        if position == 1:
            new_node.next = self.head.next
            self.head.next = new_node
        else:
            self.current = self.head.next
            for i in range(1, position):
                self.before = self.current
                self.current = self.current.next

            new_node.next = self.current
            self.before.next = new_node

        self.num_of_data += 1
# LinkedList 객체 생성
my_list = LinkedList()

my_list.append(100)
my_list.append(72)
my_list.append(325)
my_list.insert_at(5,10000)
my_list.traverse_all()
# Out:
#                                                          스페인어통번역학과 202001815 손혜인
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 105
#     103 my_list.append(72)
#     104 my_list.append(325)
# --> 105 my_list.insert_at(5,10000)
#     106 my_list.traverse_all()
#
# Cell In[1], line 93, in LinkedList.insert_at(self, position, new_data)
#      91 for i in range(1, position):
#      92     self.before = self.current
# ---> 93     self.current = self.current.next
#      95 new_node.next = self.current
#      96 self.before.next = new_node
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %% [markdown]
# position에 4이하의 자연수 넣으면 정상 구동 position에 5이상 자연수 넣으면 AttributeError: 'NoneType' object has no attribute 'next' 에러 발생

# %%
print('%80s'%'스페인어통번역학과 202001815 손혜인')
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
# LinkedList 클래스 정의
class LinkedList:

    # 초기화 메소드
    def __init__(self):
        dummy = Node("dummy")
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

    # delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
        # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    # size 메소드
    def size(self):
        return self.num_of_data 

    # traverse_all 메소드
    def traverse_all(self):
        curr_node = self.head.next
        print("head ->",end='')
        while curr_node != None:
            print("({}) -> ".format(curr_node.data), end="")
            curr_node = curr_node.next
        print("null")

    def insert_at(self, position, new_data):
        if position <= 0:
            print("ERROR")
            return

        new_node = Node(new_data)

    # 현재 리스트 길이보다 큰 위치에 데이터를 추가
        if position > self.num_of_data:
            self.append(new_data)
            return

    # 그 외의 경우
        self.current = self.head.next
        for i in range(1, position):
            self.before = self.current
            self.current = self.current.next

        new_node.next = self.current
        self.before.next = new_node

        self.num_of_data += 1

 
    # LinkedList 객체 생성
my_list = LinkedList()

my_list.append(100)
my_list.append(72)
my_list.append(325)
my_list.insert_at(9,10000)
my_list.traverse_all()
# Out:
#                                                          스페인어통번역학과 202001815 손혜인
# head ->(100) -> (72) -> (325) -> (10000) -> null

# %% [markdown]
# (정상동작)
#
# position에 0이하 정수 넣으면 ERROR print됨
#
# position이 1-4까지일때 해당 자리에 값 insert됨
#
# position이 리스트 길이보다 클 때 마지막에 new_data 삽입
